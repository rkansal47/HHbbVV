# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import matplotlib.ticker as mticker
import numpy as np

plt.style.use(hep.style.CMS)
hep.style.use("CMS")
formatter = mticker.ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-3, 3))
plt.rcParams.update({"font.size": 16})

# %% [markdown]
# In this file we will be testing our selection process using the vbf generator information. We will first be investigating whether gen jets make sense

# %%
df = pd.read_parquet("0-10.parquet")
df.columns.values.tolist()
# Out:
# [('GenHiggsEta', 0),
#  ('GenHiggsEta', 1),
#  ('GenHiggsPhi', 0),
#  ('GenHiggsPhi', 1),
#  ('GenHiggsMass', 0),
#  ('GenHiggsMass', 1),
#  ('GenHiggsPt', 0),
#  ('GenHiggsPt', 1),
#  ('GenHiggsChildren', 0),
#  ('GenHiggsChildren', 1),
#  ('GenbbEta', 0),
#  ('GenbbEta', 1),
#  ('GenbbPhi', 0),
#  ('GenbbPhi', 1),
#  ('GenbbMass', 0),
#  ('GenbbMass', 1),
#  ('GenbbPt', 0),
#  ('GenbbPt', 1),
#  ('GenVVEta', 0),
#  ('GenVVEta', 1),
#  ('GenVVPhi', 0),
#  ('GenVVPhi', 1),
#  ('GenVVMass', 0),
#  ('GenVVMass', 1),
#  ('GenVVPt', 0),
#  ('GenVVPt', 1),
#  ('Gen4qEta', 0),
#  ('Gen4qEta', 1),
#  ('Gen4qEta', 2),
#  ('Gen4qEta', 3),
#  ('Gen4qPhi', 0),
#  ('Gen4qPhi', 1),
#  ('Gen4qPhi', 2),
#  ('Gen4qPhi', 3),
#  ('Gen4qMass', 0),
#  ('Gen4qMass', 1),
#  ('Gen4qMass', 2),
#  ('Gen4qMass', 3),
#  ('Gen4qPt', 0),
#  ('Gen4qPt', 1),
#  ('Gen4qPt', 2),
#  ('Gen4qPt', 3),
#  ('ak8FatJetHbb', 0),
#  ('ak8FatJetHbb', 1),
#  ('ak8FatJetHVV', 0),
#  ('ak8FatJetHVV', 1),
#  ('ak8FatJetHVVNumProngs', 0),
#  ('vbfptGen', 0),
#  ('vbfptGen', 1),
#  ('vbfetaGen', 0),
#  ('vbfetaGen', 1),
#  ('vbfphiGen', 0),
#  ('vbfphiGen', 1),
#  ('vbfMGen', 0),
#  ('vbfMGen', 1),
#  ('vbfptSortedRand', 0),
#  ('vbfptSortedRand', 1),
#  ('vbfetaSortedRand', 0),
#  ('vbfetaSortedRand', 1),
#  ('vbfphiUnsortedRand', 0),
#  ('vbfphiUnsortedRand', 1),
#  ('vbfMUnSortedRand', 0),
#  ('vbfMUnSortedRand', 1),
#  ('vbfptSortedpt', 0),
#  ('vbfptSortedpt', 1),
#  ('vbfetaSortedpt', 0),
#  ('vbfetaSortedpt', 1),
#  ('vbfphiSortedpt', 0),
#  ('vbfphiSortedpt', 1),
#  ('vbfMSortedpt', 0),
#  ('vbfMSortedpt', 1),
#  ('vbfptSortedM', 0),
#  ('vbfptSortedM', 1),
#  ('vbfetaSortedM', 0),
#  ('vbfetaSortedM', 1),
#  ('vbfphiSortedM', 0),
#  ('vbfphiSortedM', 1),
#  ('vbfMSortedM', 0),
#  ('vbfMSortedM', 1),
#  ('vbfptSortedeta', 0),
#  ('vbfptSortedeta', 1),
#  ('vbfetaSortedeta', 0),
#  ('vbfetaSortedeta', 1),
#  ('vbfphiSortedeta', 0),
#  ('vbfphiSortedeta', 1),
#  ('vbfMSortedeta', 0),
#  ('vbfMSortedeta', 1),
#  ('nGoodVBFJetsUnsorted', 0),
#  ('nGoodVBFJetsSortedpt', 0),
#  ('nGoodVBFJetsSortedM', 0),
#  ('nGoodVBFJetsSortedeta', 0),
#  ('ak8FatJetEta', 0),
#  ('ak8FatJetEta', 1),
#  ('ak8FatJetPhi', 0),
#  ('ak8FatJetPhi', 1),
#  ('ak8FatJetMass', 0),
#  ('ak8FatJetMass', 1),
#  ('ak8FatJetPt', 0),
#  ('ak8FatJetPt', 1),
#  ('ak8FatJetMsd', 0),
#  ('ak8FatJetMsd', 1),
#  ('ak8FatJetParticleNetMD_QCD', 0),
#  ('ak8FatJetParticleNetMD_QCD', 1),
#  ('ak8FatJetParticleNetMD_Xbb', 0),
#  ('ak8FatJetParticleNetMD_Xbb', 1),
#  ('ak8FatJetParticleNet_Th4q', 0),
#  ('ak8FatJetParticleNet_Th4q', 1),
#  ('ak8FatJetParticleNetMass', 0),
#  ('ak8FatJetParticleNetMass', 1),
#  ('ak8FatJetPt_JES_up', 0),
#  ('ak8FatJetPt_JES_up', 1),
#  ('ak8FatJetPt_JES_down', 0),
#  ('ak8FatJetPt_JES_down', 1),
#  ('ak8FatJetPt_JER_up', 0),
#  ('ak8FatJetPt_JER_up', 1),
#  ('ak8FatJetPt_JER_down', 0),
#  ('ak8FatJetPt_JER_down', 1),
#  ('ak8FatJetMsd_JMS_down', 0),
#  ('ak8FatJetMsd_JMS_down', 1),
#  ('ak8FatJetMsd_JMS_up', 0),
#  ('ak8FatJetMsd_JMS_up', 1),
#  ('ak8FatJetMsd_JMR_down', 0),
#  ('ak8FatJetMsd_JMR_down', 1),
#  ('ak8FatJetMsd_JMR_up', 0),
#  ('ak8FatJetMsd_JMR_up', 1),
#  ('ak8FatJetParticleNetMass_JMS_down', 0),
#  ('ak8FatJetParticleNetMass_JMS_down', 1),
#  ('ak8FatJetParticleNetMass_JMS_up', 0),
#  ('ak8FatJetParticleNetMass_JMS_up', 1),
#  ('ak8FatJetParticleNetMass_JMR_down', 0),
#  ('ak8FatJetParticleNetMass_JMR_down', 1),
#  ('ak8FatJetParticleNetMass_JMR_up', 0),
#  ('ak8FatJetParticleNetMass_JMR_up', 1),
#  ('ak8FatJetParticleNetMD_Txbb', 0),
#  ('ak8FatJetParticleNetMD_Txbb', 1),
#  ('DijetPt', 0),
#  ('DijetMass', 0),
#  ('DijetEta', 0),
#  ('bbFatJetPtOverDijetPt', 0),
#  ('VVFatJetPtOverDijetPt', 0),
#  ('VVFatJetPtOverbbFatJetPt', 0),
#  ('DijetPt_JES_up', 0),
#  ('DijetMass_JES_up', 0),
#  ('DijetEta_JES_up', 0),
#  ('bbFatJetPtOverDijetPt_JES_up', 0),
#  ('VVFatJetPtOverDijetPt_JES_up', 0),
#  ('VVFatJetPtOverbbFatJetPt_JES_up', 0),
#  ('DijetPt_JES_down', 0),
#  ('DijetMass_JES_down', 0),
#  ('DijetEta_JES_down', 0),
#  ('bbFatJetPtOverDijetPt_JES_down', 0),
#  ('VVFatJetPtOverDijetPt_JES_down', 0),
#  ('VVFatJetPtOverbbFatJetPt_JES_down', 0),
#  ('DijetPt_JER_up', 0),
#  ('DijetMass_JER_up', 0),
#  ('DijetEta_JER_up', 0),
#  ('bbFatJetPtOverDijetPt_JER_up', 0),
#  ('VVFatJetPtOverDijetPt_JER_up', 0),
#  ('VVFatJetPtOverbbFatJetPt_JER_up', 0),
#  ('DijetPt_JER_down', 0),
#  ('DijetMass_JER_down', 0),
#  ('DijetEta_JER_down', 0),
#  ('bbFatJetPtOverDijetPt_JER_down', 0),
#  ('VVFatJetPtOverDijetPt_JER_down', 0),
#  ('VVFatJetPtOverbbFatJetPt_JER_down', 0),
#  ('DijetPt_JMS_down', 0),
#  ('DijetMass_JMS_down', 0),
#  ('DijetEta_JMS_down', 0),
#  ('bbFatJetPtOverDijetPt_JMS_down', 0),
#  ('VVFatJetPtOverDijetPt_JMS_down', 0),
#  ('VVFatJetPtOverbbFatJetPt_JMS_down', 0),
#  ('DijetPt_JMS_up', 0),
#  ('DijetMass_JMS_up', 0),
#  ('DijetEta_JMS_up', 0),
#  ('bbFatJetPtOverDijetPt_JMS_up', 0),
#  ('VVFatJetPtOverDijetPt_JMS_up', 0),
#  ('VVFatJetPtOverbbFatJetPt_JMS_up', 0),
#  ('DijetPt_JMR_down', 0),
#  ('DijetMass_JMR_down', 0),
#  ('DijetEta_JMR_down', 0),
#  ('bbFatJetPtOverDijetPt_JMR_down', 0),
#  ('VVFatJetPtOverDijetPt_JMR_down', 0),
#  ('VVFatJetPtOverbbFatJetPt_JMR_down', 0),
#  ('DijetPt_JMR_up', 0),
#  ('DijetMass_JMR_up', 0),
#  ('DijetEta_JMR_up', 0),
#  ('bbFatJetPtOverDijetPt_JMR_up', 0),
#  ('VVFatJetPtOverDijetPt_JMR_up', 0),
#  ('VVFatJetPtOverbbFatJetPt_JMR_up', 0),
#  ('MET_pt', 0),
#  ('nGoodMuons', 0),
#  ('nGoodElectrons', 0),
#  ('nGoodJets', 0),
#  ('weight', 0),
#  ('weight_noxsec', 0),
#  ('lp_sf_lnN', 0),
#  ('lp_sf_lnN', 1),
#  ('lp_sf_lnN', 2),
#  ('lp_sf_lnN', 3),
#  ('lp_sf_lnN', 4),
#  ('lp_sf_lnN', 5),
#  ('lp_sf_lnN', 6),
#  ('lp_sf_lnN', 7),
#  ('lp_sf_lnN', 8),
#  ('lp_sf_lnN', 9),
#  ('lp_sf_lnN', 10),
#  ('lp_sf_lnN', 11),
#  ('lp_sf_lnN', 12),
#  ('lp_sf_lnN', 13),
#  ('lp_sf_lnN', 14),
#  ('lp_sf_lnN', 15),
#  ('lp_sf_lnN', 16),
#  ('lp_sf_lnN', 17),
#  ('lp_sf_lnN', 18),
#  ('lp_sf_lnN', 19),
#  ('lp_sf_lnN', 20),
#  ('lp_sf_lnN', 21),
#  ('lp_sf_lnN', 22),
#  ('lp_sf_lnN', 23),
#  ('lp_sf_lnN', 24),
#  ('lp_sf_lnN', 25),
#  ('lp_sf_lnN', 26),
#  ('lp_sf_lnN', 27),
#  ('lp_sf_lnN', 28),
#  ('lp_sf_lnN', 29),
#  ('lp_sf_lnN', 30),
#  ('lp_sf_lnN', 31),
#  ('lp_sf_lnN', 32),
#  ('lp_sf_lnN', 33),
#  ('lp_sf_lnN', 34),
#  ('lp_sf_lnN', 35),
#  ('lp_sf_lnN', 36),
#  ('lp_sf_lnN', 37),
#  ('lp_sf_lnN', 38),
#  ('lp_sf_lnN', 39),
#  ('lp_sf_lnN', 40),
#  ('lp_sf_lnN', 41),
#  ('lp_sf_lnN', 42),
#  ('lp_sf_lnN', 43),
#  ('lp_sf_lnN', 44),
#  ('lp_sf_lnN', 45),
#  ('lp_sf_lnN', 46),
#  ('lp_sf_lnN', 47),
#  ('lp_sf_lnN', 48),
#  ('lp_sf_lnN', 49),
#  ('lp_sf_lnN', 50),
#  ('lp_sf_lnN', 51),
#  ('lp_sf_lnN', 52),
#  ('lp_sf_lnN', 53),
#  ('lp_sf_lnN', 54),
#  ('lp_sf_lnN', 55),
#  ('lp_sf_lnN', 56),
#  ('lp_sf_lnN', 57),
#  ('lp_sf_lnN', 58),
#  ('lp_sf_lnN', 59),
#  ('lp_sf_lnN', 60),
#  ('lp_sf_lnN', 61),
#  ('lp_sf_lnN', 62),
#  ('lp_sf_lnN', 63),
#  ('lp_sf_lnN', 64),
#  ('lp_sf_lnN', 65),
#  ('lp_sf_lnN', 66),
#  ('lp_sf_lnN', 67),
#  ('lp_sf_lnN', 68),
#  ('lp_sf_lnN', 69),
#  ('lp_sf_lnN', 70),
#  ('lp_sf_lnN', 71),
#  ('lp_sf_lnN', 72),
#  ('lp_sf_lnN', 73),
#  ('lp_sf_lnN', 74),
#  ('lp_sf_lnN', 75),
#  ('lp_sf_lnN', 76),
#  ('lp_sf_lnN', 77),
#  ('lp_sf_lnN', 78),
#  ('lp_sf_lnN', 79),
#  ('lp_sf_lnN', 80),
#  ('lp_sf_lnN', 81),
#  ('lp_sf_lnN', 82),
#  ('lp_sf_lnN', 83),
#  ('lp_sf_lnN', 84),
#  ('lp_sf_lnN', 85),
#  ('lp_sf_lnN', 86),
#  ('lp_sf_lnN', 87),
#  ('lp_sf_lnN', 88),
#  ('lp_sf_lnN', 89),
#  ('lp_sf_lnN', 90),
#  ('lp_sf_lnN', 91),
#  ('lp_sf_lnN', 92),
#  ('lp_sf_lnN', 93),
#  ('lp_sf_lnN', 94),
#  ('lp_sf_lnN', 95),
#  ('lp_sf_lnN', 96),
#  ('lp_sf_lnN', 97),
#  ('lp_sf_lnN', 98),
#  ('lp_sf_lnN', 99),
#  ('lp_sf_lnN', 100),
#  ('lp_sf_lnN', 101),
#  ('lp_sf_lnN', 102),
#  ('lp_sf_lnN', 103),
#  ('lp_sf_lnN', 104),
#  ('lp_sf_lnN', 105),
#  ('lp_sf_lnN', 106),
#  ('lp_sf_lnN', 107),
#  ('lp_sf_lnN', 108),
#  ('lp_sf_lnN', 109),
#  ('lp_sf_lnN', 110),
#  ('lp_sf_lnN', 111),
#  ('lp_sf_lnN', 112),
#  ('lp_sf_lnN', 113),
#  ('lp_sf_lnN', 114),
#  ('lp_sf_lnN', 115),
#  ('lp_sf_lnN', 116),
#  ('lp_sf_lnN', 117),
#  ('lp_sf_lnN', 118),
#  ('lp_sf_lnN', 119),
#  ('lp_sf_lnN', 120),
#  ('lp_sf_lnN', 121),
#  ('lp_sf_lnN', 122),
#  ('lp_sf_lnN', 123),
#  ('lp_sf_lnN', 124),
#  ('lp_sf_lnN', 125),
#  ('lp_sf_lnN', 126),
#  ('lp_sf_lnN', 127),
#  ('lp_sf_lnN', 128),
#  ('lp_sf_lnN', 129),
#  ('lp_sf_lnN', 130),
#  ('lp_sf_lnN', 131),
#  ('lp_sf_lnN', 132),
#  ('lp_sf_lnN', 133),
#  ('lp_sf_lnN', 134),
#  ('lp_sf_lnN', 135),
#  ('lp_sf_lnN', 136),
#  ('lp_sf_lnN', 137),
#  ('lp_sf_lnN', 138),
#  ('lp_sf_lnN', 139),
#  ('lp_sf_lnN', 140),
#  ('lp_sf_lnN', 141),
#  ('lp_sf_lnN', 142),
#  ('lp_sf_lnN', 143),
#  ('lp_sf_lnN', 144),
#  ('lp_sf_lnN', 145),
#  ('lp_sf_lnN', 146),
#  ('lp_sf_lnN', 147),
#  ('lp_sf_lnN', 148),
#  ('lp_sf_lnN', 149),
#  ('lp_sf_lnN', 150),
#  ('lp_sf_lnN', 151),
#  ('lp_sf_lnN', 152),
#  ('lp_sf_lnN', 153),
#  ('lp_sf_lnN', 154),
#  ('lp_sf_lnN', 155),
#  ('lp_sf_lnN', 156),
#  ('lp_sf_lnN', 157),
#  ('lp_sf_lnN', 158),
#  ('lp_sf_lnN', 159),
#  ('lp_sf_lnN', 160),
#  ('lp_sf_lnN', 161),
#  ('lp_sf_lnN', 162),
#  ('lp_sf_lnN', 163),
#  ('lp_sf_lnN', 164),
#  ('lp_sf_lnN', 165),
#  ('lp_sf_lnN', 166),
#  ('lp_sf_lnN', 167),
#  ('lp_sf_lnN', 168),
#  ('lp_sf_lnN', 169),
#  ('lp_sf_lnN', 170),
#  ('lp_sf_lnN', 171),
#  ('lp_sf_lnN', 172),
#  ('lp_sf_lnN', 173),
#  ('lp_sf_lnN', 174),
#  ('lp_sf_lnN', 175),
#  ('lp_sf_lnN', 176),
#  ('lp_sf_lnN', 177),
#  ('lp_sf_lnN', 178),
#  ('lp_sf_lnN', 179),
#  ('lp_sf_lnN', 180),
#  ('lp_sf_lnN', 181),
#  ('lp_sf_lnN', 182),
#  ('lp_sf_lnN', 183),
#  ('lp_sf_lnN', 184),
#  ('lp_sf_lnN', 185),
#  ('lp_sf_lnN', 186),
#  ('lp_sf_lnN', 187),
#  ('lp_sf_lnN', 188),
#  ('lp_sf_lnN', 189),
#  ('lp_sf_lnN', 190),
#  ('lp_sf_lnN', 191),
#  ('lp_sf_lnN', 192),
#  ('lp_sf_lnN', 193),
#  ('lp_sf_lnN', 194),
#  ('lp_sf_lnN', 195),
#  ('lp_sf_lnN', 196),
#  ('lp_sf_lnN', 197),
#  ('lp_sf_lnN', 198),
#  ('lp_sf_lnN', 199),
#  ('lp_sf_lnN', 200),
#  ('lp_sf_lnN', 201),
#  ('lp_sf_sys_down', 0),
#  ('lp_sf_sys_down', 1),
#  ('lp_sf_sys_up', 0),
#  ('lp_sf_sys_up', 1),
#  ('lp_sf_double_matched_event', 0),
#  ('lp_sf_double_matched_event', 1),
#  ('lp_sf_unmatched_quarks', 0),
#  ('lp_sf_unmatched_quarks', 1),
#  ('lp_sf_num_sjpt_gt350', 0),
#  ('lp_sf_num_sjpt_gt350', 1)]

# %% [markdown]
# bbSkimmer modified gives us the two VBF jets which we will be able to access and manipulate. it also gives us the results of cuts on the events (there needs to be atleast 2 VBF jets). We can apply these filters and graph the kinematic variables. We can also record the before and after applying these cuts.

# %%
# Apply lepton veto selections ($N_\mu =0$ and $N_e=0$)
print(np.shape(df))
df_em = df[(df[("nGoodMuons", 0)] == 0) & (df[("nGoodElectrons", 0)] == 0)]

# 2 vbf jets
df_vbf = df[(df[("nGoodVBFJetsUnsorted", 0)] >= 2)]

# lepton veto and 2 vbf jets
df_unsorted = df[
    (df[("nGoodMuons", 0)] == 0)
    & (df[("nGoodElectrons", 0)] == 0)
    & (df[("nGoodVBFJetsUnsorted", 0)] >= 2)
    & (df[("nGoodJets", 0)] == 0)
]
df_sorted_pt = df[
    (df[("nGoodMuons", 0)] == 0)
    & (df[("nGoodElectrons", 0)] == 0)
    & (df[("nGoodVBFJetsSortedpt", 0)] >= 2)
    & (df[("nGoodJets", 0)] == 0)
]
df_sorted_M = df[
    (df[("nGoodMuons", 0)] == 0)
    & (df[("nGoodElectrons", 0)] == 0)
    & (df[("nGoodVBFJetsSortedM", 0)] >= 2)
    & (df[("nGoodJets", 0)] == 0)
]
df_sorted_eta = df[
    (df[("nGoodMuons", 0)] == 0)
    & (df[("nGoodElectrons", 0)] == 0)
    & (df[("nGoodVBFJetsSortedeta", 0)] >= 2)
    & (df[("nGoodJets", 0)] == 0)
]


# generate all variables that are needed for the ak8 jet selections in VBF HH4b paper.
# df[('DijetDeltaPhi', 0)] = np.abs(df[('ak8FatJetPhi', 0)] - df[('ak8FatJetPhi', 1)])
# df[('DijetDeltaEta', 0)] = np.abs(df[('ak8FatJetEta', 0)] - df[('ak8FatJetEta', 1)])
print(
    np.shape(df)[0],
    np.shape(df_unsorted)[0],
    np.shape(df_sorted_pt)[0],
    np.shape(df_sorted_M)[0],
    np.shape(df_sorted_eta)[0],
)
# Out:
# (2901, 407)
# 2901 1411 666 790 805

# %% [markdown]
# Graphing the variables for our matched jets:

# %%
import numpy as np


# Define the delta R function
def deltaR(eta1, phi1, eta2, phi2):
    deta = eta1 - eta2
    dphi = np.abs(phi1 - phi2)
    dphi[dphi > np.pi] -= 2 * np.pi  # Take care of circular limits
    return np.sqrt(deta**2 + dphi**2)


# Create a dictionary mapping sorting methods to their dataframes
sorting_methods_to_dfs = {
    "Rand": df_unsorted,
    "pt": df_sorted_pt,
    "M": df_sorted_M,
    "eta": df_sorted_eta,
}

# Iterate over each DataFrame and modify the column names
for df_name, df_method in sorting_methods_to_dfs.items():
    df_method.rename(
        columns={("vbfphiUnsortedRand", jet): ("vbfphiSortedRand", jet) for jet in [0, 1]},
        inplace=True,
    )
    df_method.rename(
        columns={("vbfMUnsortedRand", jet): ("vbfMSortedRand", jet) for jet in [0, 1]}, inplace=True
    )

for df_name, df_method in sorting_methods_to_dfs.items():
    print(f"{df_name} DataFrame:\n")
    print(df_method.columns.values.tolist())
    print("\n---\n")


# Iterate over each sorting method and calculate delta R
for method, df_method in sorting_methods_to_dfs.items():
    for jet in [0, 1]:
        eta_gen = df_method[(f"vbfetaGen", jet)]
        phi_gen = df_method[(f"vbfphiGen", jet)]

        eta_sorted = df_method[(f"vbfetaSorted{method}", jet)]
        phi_sorted = df_method[(f"vbfphiSorted{method}", jet)]

        df_method[(f"deltaR_{method}", jet)] = deltaR(eta_gen, phi_gen, eta_sorted, phi_sorted)

# Print DataFrames to check results
for df_name, df_method in sorting_methods_to_dfs.items():
    print(f"{df_name} DataFrame:\n")
    print(df_method)
    print("\n---\n")
# Out:
# /tmp/ipykernel_2378181/1333567728.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfphiUnsortedRand', jet): ('vbfphiSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfMUnsortedRand', jet): ('vbfMSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfphiUnsortedRand', jet): ('vbfphiSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfMUnsortedRand', jet): ('vbfMSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfphiUnsortedRand', jet): ('vbfphiSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfMUnsortedRand', jet): ('vbfMSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfphiUnsortedRand', jet): ('vbfphiSortedRand', jet) for jet in [0, 1]}, inplace=True)
# /tmp/ipykernel_2378181/1333567728.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_method.rename(columns={('vbfMUnsortedRand', jet): ('vbfMSortedRand', jet) for jet in [0, 1]}, inplace=True)
# Rand DataFrame:
#
#      GenHiggsEta           GenHiggsPhi           GenHiggsMass         \
#                0         1           0         1            0      1
# 3       0.485352  0.677734   -0.587891 -0.566406        125.0  125.0
# 5       0.196289 -0.335938    2.843750 -1.167969        125.0  125.0
# 10     -0.251953  2.039062    3.023438 -0.309570        125.0  125.0
# 12     -4.125000  0.886719   -2.140625 -3.085938        125.0  125.0
# 13     -0.377930 -1.132812   -1.550781  1.664062        125.0  125.0
# ...          ...       ...         ...       ...          ...    ...
# 2893   -2.031250  1.242188    1.464844 -1.664062        125.0  125.0
# 2894   -1.460938  1.027344    2.585938 -0.071045        125.0  125.0
# 2896    1.027344 -1.554688    1.925781 -1.304688        125.0  125.0
# 2898   -0.589844 -0.937500   -1.777344  1.894531        125.0  125.0
# 2900   -0.253906  0.446289   -1.839844  0.550781        125.0  125.0
#
#      GenHiggsPt        GenHiggsChildren      ... lp_sf_sys_down                \
#               0      1                0   1  ...              0             1
# 3       674.000  469.0               24   5  ...   1.000000e+00  2.079630e-08
# 5       435.000  383.0               24   5  ...   1.639207e-01  2.674655e-01
# 10      376.000  302.0               24   5  ...   8.279122e-10  8.664215e-01
# 12       58.625  307.0               24   5  ...   1.000000e+00  6.135069e-01
# 13      481.000  596.0                5  24  ...   8.606327e-02  1.292904e-19
# ...         ...    ...              ...  ..  ...            ...           ...
# 2893    330.000  353.0                5  24  ...   3.031049e-02  2.994285e-01
# 2894    356.000  316.0               24   5  ...   6.765076e-01  4.386813e-01
# 2896    590.000  486.0                5  24  ...   1.712477e-16  6.529232e-02
# 2898    395.000  337.0                5  24  ...   8.117058e-01  1.081481e-01
# 2900    202.000  554.0               24   5  ...   2.229396e+00  1.000000e+00
#
#      lp_sf_sys_up             lp_sf_double_matched_event       \
#                 0           1                          0    1
# 3        1.000000  438.928223                        1.0  0.0
# 5       12.847026    2.543565                        0.0  0.0
# 10       0.513515    4.280859                        0.0  0.0
# 12       1.000000    3.745392                        1.0  0.0
# 13       0.636210    1.263351                        0.0  0.0
# ...           ...         ...                        ...  ...
# 2893     0.673343    0.749937                        0.0  0.0
# 2894     3.013758    2.087785                        0.0  0.0
# 2896   966.896301    1.488282                        0.0  1.0
# 2898     5.188664    0.891832                        0.0  0.0
# 2900     9.468206    1.000000                        0.0  1.0
#
#      lp_sf_unmatched_quarks      lp_sf_num_sjpt_gt350
#                           0    1                    0    1
# 3                       1.0  1.0                  1.0  1.0
# 5                       1.0  1.0                  0.0  0.0
# 10                      1.0  1.0                  0.0  0.0
# 12                      1.0  0.0                  1.0  0.0
# 13                      0.0  0.0                  0.0  1.0
# ...                     ...  ...                  ...  ...
# 2893                    0.0  0.0                  0.0  0.0
# 2894                    1.0  0.0                  0.0  0.0
# 2896                    0.0  0.0                  1.0  0.0
# 2898                    0.0  1.0                  0.0  0.0
# 2900                    1.0  1.0                  0.0  1.0
#
# [1411 rows x 407 columns]
#
# ---
#
# pt DataFrame:
#
#      GenHiggsEta           GenHiggsPhi           GenHiggsMass         \
#                0         1           0         1            0      1
# 10     -0.251953  2.039062    3.023438 -0.309570        125.0  125.0
# 16      0.619141 -1.382812    1.710938 -1.277344        125.0  125.0
# 18     -0.498047  1.140625    2.640625 -0.364258        125.0  125.0
# 19     -0.403320  0.301758    1.039062 -2.406250        125.0  125.0
# 20     -0.375000 -1.660156    0.260742 -2.984375        125.0  125.0
# ...          ...       ...         ...       ...          ...    ...
# 2888   -0.021118 -0.988281    0.198730 -2.945312        125.0  125.0
# 2893   -2.031250  1.242188    1.464844 -1.664062        125.0  125.0
# 2894   -1.460938  1.027344    2.585938 -0.071045        125.0  125.0
# 2896    1.027344 -1.554688    1.925781 -1.304688        125.0  125.0
# 2898   -0.589844 -0.937500   -1.777344  1.894531        125.0  125.0
#
#      GenHiggsPt        GenHiggsChildren      ... lp_sf_sys_down                \
#               0      1                0   1  ...              0             1
# 10        376.0  302.0               24   5  ...   8.279122e-10  8.664215e-01
# 16        402.0  367.0                5  24  ...   2.830067e-01  2.223975e-11
# 18        333.0  353.0                5  24  ...   1.460015e-01  1.168572e-01
# 19        387.0  465.0                5  24  ...   3.072697e-01  8.369941e-02
# 20        520.0  584.0               24   5  ...   3.494380e-20  1.775123e+00
# ...         ...    ...              ...  ..  ...            ...           ...
# 2888      405.0  480.0               24   5  ...   1.046018e+00  1.064279e-01
# 2893      330.0  353.0                5  24  ...   3.031049e-02  2.994285e-01
# 2894      356.0  316.0               24   5  ...   6.765076e-01  4.386813e-01
# 2896      590.0  486.0                5  24  ...   1.712477e-16  6.529232e-02
# 2898      395.0  337.0                5  24  ...   8.117058e-01  1.081481e-01
#
#      lp_sf_sys_up            lp_sf_double_matched_event       \
#                 0          1                          0    1
# 10       0.513515   4.280859                        0.0  0.0
# 16       1.417587   0.059983                        0.0  0.0
# 18       2.821076   3.007978                        1.0  0.0
# 19       3.579396   1.760923                        0.0  0.0
# 20     506.768951  13.775488                        0.0  0.0
# ...           ...        ...                        ...  ...
# 2888     4.962087   0.960079                        0.0  1.0
# 2893     0.673343   0.749937                        0.0  0.0
# 2894     3.013758   2.087785                        0.0  0.0
# 2896   966.896301   1.488282                        0.0  1.0
# 2898     5.188664   0.891832                        0.0  0.0
#
#      lp_sf_unmatched_quarks      lp_sf_num_sjpt_gt350
#                           0    1                    0    1
# 10                      1.0  1.0                  0.0  0.0
# 16                      0.0  1.0                  0.0  0.0
# 18                      0.0  1.0                  0.0  0.0
# 19                      1.0  2.0                  0.0  0.0
# 20                      0.0  1.0                  1.0  0.0
# ...                     ...  ...                  ...  ...
# 2888                    0.0  0.0                  0.0  0.0
# 2893                    0.0  0.0                  0.0  0.0
# 2894                    1.0  0.0                  0.0  0.0
# 2896                    0.0  0.0                  1.0  0.0
# 2898                    0.0  1.0                  0.0  0.0
#
# [666 rows x 407 columns]
#
# ---
#
# M DataFrame:
#
#      GenHiggsEta           GenHiggsPhi           GenHiggsMass         \
#                0         1           0         1            0      1
# 10     -0.251953  2.039062    3.023438 -0.309570        125.0  125.0
# 16      0.619141 -1.382812    1.710938 -1.277344        125.0  125.0
# 18     -0.498047  1.140625    2.640625 -0.364258        125.0  125.0
# 19     -0.403320  0.301758    1.039062 -2.406250        125.0  125.0
# 20     -0.375000 -1.660156    0.260742 -2.984375        125.0  125.0
# ...          ...       ...         ...       ...          ...    ...
# 2888   -0.021118 -0.988281    0.198730 -2.945312        125.0  125.0
# 2893   -2.031250  1.242188    1.464844 -1.664062        125.0  125.0
# 2894   -1.460938  1.027344    2.585938 -0.071045        125.0  125.0
# 2896    1.027344 -1.554688    1.925781 -1.304688        125.0  125.0
# 2898   -0.589844 -0.937500   -1.777344  1.894531        125.0  125.0
#
#      GenHiggsPt        GenHiggsChildren      ... lp_sf_sys_down                \
#               0      1                0   1  ...              0             1
# 10        376.0  302.0               24   5  ...   8.279122e-10  8.664215e-01
# 16        402.0  367.0                5  24  ...   2.830067e-01  2.223975e-11
# 18        333.0  353.0                5  24  ...   1.460015e-01  1.168572e-01
# 19        387.0  465.0                5  24  ...   3.072697e-01  8.369941e-02
# 20        520.0  584.0               24   5  ...   3.494380e-20  1.775123e+00
# ...         ...    ...              ...  ..  ...            ...           ...
# 2888      405.0  480.0               24   5  ...   1.046018e+00  1.064279e-01
# 2893      330.0  353.0                5  24  ...   3.031049e-02  2.994285e-01
# 2894      356.0  316.0               24   5  ...   6.765076e-01  4.386813e-01
# 2896      590.0  486.0                5  24  ...   1.712477e-16  6.529232e-02
# 2898      395.0  337.0                5  24  ...   8.117058e-01  1.081481e-01
#
#      lp_sf_sys_up            lp_sf_double_matched_event       \
#                 0          1                          0    1
# 10       0.513515   4.280859                        0.0  0.0
# 16       1.417587   0.059983                        0.0  0.0
# 18       2.821076   3.007978                        1.0  0.0
# 19       3.579396   1.760923                        0.0  0.0
# 20     506.768951  13.775488                        0.0  0.0
# ...           ...        ...                        ...  ...
# 2888     4.962087   0.960079                        0.0  1.0
# 2893     0.673343   0.749937                        0.0  0.0
# 2894     3.013758   2.087785                        0.0  0.0
# 2896   966.896301   1.488282                        0.0  1.0
# 2898     5.188664   0.891832                        0.0  0.0
#
#      lp_sf_unmatched_quarks      lp_sf_num_sjpt_gt350
#                           0    1                    0    1
# 10                      1.0  1.0                  0.0  0.0
# 16                      0.0  1.0                  0.0  0.0
# 18                      0.0  1.0                  0.0  0.0
# 19                      1.0  2.0                  0.0  0.0
# 20                      0.0  1.0                  1.0  0.0
# ...                     ...  ...                  ...  ...
# 2888                    0.0  0.0                  0.0  0.0
# 2893                    0.0  0.0                  0.0  0.0
# 2894                    1.0  0.0                  0.0  0.0
# 2896                    0.0  0.0                  1.0  0.0
# 2898                    0.0  1.0                  0.0  0.0
#
# [790 rows x 407 columns]
#
# ---
#
# eta DataFrame:
#
#      GenHiggsEta           GenHiggsPhi           GenHiggsMass         \
#                0         1           0         1            0      1
# 10     -0.251953  2.039062    3.023438 -0.309570        125.0  125.0
# 16      0.619141 -1.382812    1.710938 -1.277344        125.0  125.0
# 18     -0.498047  1.140625    2.640625 -0.364258        125.0  125.0
# 19     -0.403320  0.301758    1.039062 -2.406250        125.0  125.0
# 20     -0.375000 -1.660156    0.260742 -2.984375        125.0  125.0
# ...          ...       ...         ...       ...          ...    ...
# 2888   -0.021118 -0.988281    0.198730 -2.945312        125.0  125.0
# 2893   -2.031250  1.242188    1.464844 -1.664062        125.0  125.0
# 2894   -1.460938  1.027344    2.585938 -0.071045        125.0  125.0
# 2896    1.027344 -1.554688    1.925781 -1.304688        125.0  125.0
# 2898   -0.589844 -0.937500   -1.777344  1.894531        125.0  125.0
#
#      GenHiggsPt        GenHiggsChildren      ... lp_sf_sys_down                \
#               0      1                0   1  ...              0             1
# 10        376.0  302.0               24   5  ...   8.279122e-10  8.664215e-01
# 16        402.0  367.0                5  24  ...   2.830067e-01  2.223975e-11
# 18        333.0  353.0                5  24  ...   1.460015e-01  1.168572e-01
# 19        387.0  465.0                5  24  ...   3.072697e-01  8.369941e-02
# 20        520.0  584.0               24   5  ...   3.494380e-20  1.775123e+00
# ...         ...    ...              ...  ..  ...            ...           ...
# 2888      405.0  480.0               24   5  ...   1.046018e+00  1.064279e-01
# 2893      330.0  353.0                5  24  ...   3.031049e-02  2.994285e-01
# 2894      356.0  316.0               24   5  ...   6.765076e-01  4.386813e-01
# 2896      590.0  486.0                5  24  ...   1.712477e-16  6.529232e-02
# 2898      395.0  337.0                5  24  ...   8.117058e-01  1.081481e-01
#
#      lp_sf_sys_up            lp_sf_double_matched_event       \
#                 0          1                          0    1
# 10       0.513515   4.280859                        0.0  0.0
# 16       1.417587   0.059983                        0.0  0.0
# 18       2.821076   3.007978                        1.0  0.0
# 19       3.579396   1.760923                        0.0  0.0
# 20     506.768951  13.775488                        0.0  0.0
# ...           ...        ...                        ...  ...
# 2888     4.962087   0.960079                        0.0  1.0
# 2893     0.673343   0.749937                        0.0  0.0
# 2894     3.013758   2.087785                        0.0  0.0
# 2896   966.896301   1.488282                        0.0  1.0
# 2898     5.188664   0.891832                        0.0  0.0
#
#      lp_sf_unmatched_quarks      lp_sf_num_sjpt_gt350
#                           0    1                    0    1
# 10                      1.0  1.0                  0.0  0.0
# 16                      0.0  1.0                  0.0  0.0
# 18                      0.0  1.0                  0.0  0.0
# 19                      1.0  2.0                  0.0  0.0
# 20                      0.0  1.0                  1.0  0.0
# ...                     ...  ...                  ...  ...
# 2888                    0.0  0.0                  0.0  0.0
# 2893                    0.0  0.0                  0.0  0.0
# 2894                    1.0  0.0                  0.0  0.0
# 2896                    0.0  0.0                  1.0  0.0
# 2898                    0.0  1.0                  0.0  0.0
#
# [805 rows x 407 columns]
#
# ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vbfphiSortedRand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:824, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#
# KeyError: 'vbfphiSortedRand'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 38
#      35         phi_gen = df_method[(f'vbfphiGen', jet)]
#      37         eta_sorted = df_method[(f'vbfetaSorted{method}', jet)]
# ---> 38         phi_sorted = df_method[(f'vbfphiSorted{method}', jet)]
#      40         df_method[(f'deltaR_{method}', jet)] = deltaR(eta_gen, phi_gen, eta_sorted, phi_sorted)
#      42 # Print DataFrames to check results
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/core/frame.py:3815, in DataFrame._getitem_multilevel(self, key)
#    3813 def _getitem_multilevel(self, key):
#    3814     # self.columns is a MultiIndex
# -> 3815     loc = self.columns.get_loc(key)
#    3816     if isinstance(loc, (slice, np.ndarray)):
#    3817         new_columns = self.columns[loc]
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2825, in MultiIndex.get_loc(self, key)
#    2821 if keylen == self.nlevels and self.is_unique:
#    2822     # TODO: what if we have an IntervalIndex level?
#    2823     #  i.e. do we need _index_as_unique on that level?
#    2824     try:
# -> 2825         return self._engine.get_loc(key)
#    2826     except TypeError:
#    2827         # e.g. test_partial_slicing_with_multiindex partial string slicing
#    2828         loc, _ = self.get_loc_level(key, list(range(self.nlevels)))
#
# File ~/mambaforge/envs/cofenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:827, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: ('vbfphiSortedRand', 0)
