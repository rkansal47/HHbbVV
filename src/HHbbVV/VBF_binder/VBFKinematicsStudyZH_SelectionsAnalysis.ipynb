# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import matplotlib.ticker as mticker
import numpy as np

import uproot
import awkward as ak
from coffea import nanoevents

from coffea.nanoevents.methods.base import NanoEventsArray
from coffea.analysis_tools import Weights, PackedSelection
from coffea.nanoevents.methods import nanoaod
from coffea.nanoevents.methods import vector
from coffea.lookup_tools.dense_lookup import dense_lookup

from HHbbVV.processors.utils import pad_val

plt.style.use(hep.style.CMS)
hep.style.use("CMS")
formatter = mticker.ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-3, 3))
plt.rcParams.update({"font.size": 24})

import warnings

warnings.filterwarnings("ignore")

# %%
from datetime import datetime
from pathlib import Path

MAIN_DIR = Path("../../../")
samples_dir = MAIN_DIR / "../data/skimmer/24Mar5AllYears"
# samples_dir = "/ceph/cms/store/user/annava/projects/HHbbVV/24Mar5AllYears"
year = "2016"

# date = "24Mar6"
date = datetime.now().strftime("%Y%m%d")
plot_dir = MAIN_DIR / f"plots/Kinematics/{date}/"
plot_dir.mkdir(parents=True, exist_ok=True)

# %%
Z_PDGID = 23
W_PDGID = 24
HIGGS_PDGID = 25
b_PDGID = 5
GEN_FLAGS = ["fromHardProcess", "isLastCopy"]

# %% [markdown]
# Look at single SM VBF HH signal NanoAOD file

# %%
events = nanoevents.NanoEventsFactory.from_root(
    # "root://cmseos.fnal.gov///store/user/lpcpfnano/cmantill/v2_3/2018/HH/VBF_HHTobbVV_CV_1_C2V__C3_1_TuneCP5_13TeV-madgraph-pythia8/VBF_HHTobbVV_CV_1_C2V_1_C3_1/220808_150149/0000/nano_mc2018_1-1.root",
    "root://cmseos.fnal.gov///store/user/lpcpfnano/cmantill/v2_3/2018/HH/VBF_HHTobbVV_CV_1_C2V_0_C3_1_TuneCP5_13TeV-madgraph-pythia8/VBF_HHTobbVV_CV_1_C2V_0_C3_1/220808_150000/0000/nano_mc2018_1-1.root",
    schemaclass=nanoevents.NanoAODSchema,
).events()

# %% [markdown]
# Get generator-level Higgs and Vs

# %%
higgs = events.GenPart[
    (abs(events.GenPart.pdgId) == HIGGS_PDGID) * events.GenPart.hasFlags(GEN_FLAGS)
]

higgs_children = higgs.children

# finding bb and VV children
is_bb = abs(higgs_children.pdgId) == b_PDGID
is_VV = (abs(higgs_children.pdgId) == W_PDGID) + (abs(higgs_children.pdgId) == Z_PDGID)

Hbb = higgs[ak.any(is_bb, axis=2)]
HVV = higgs[ak.any(is_VV, axis=2)]

# make sure we're only getting one Higgs
Hbb = ak.pad_none(Hbb, 1, axis=1)[:, 0]
HVV = ak.pad_none(HVV, 1, axis=1)[:, 0]

vs = events.GenPart[((abs(events.GenPart.pdgId) == 24)) * events.GenPart.hasFlags(GEN_FLAGS)]

# vbf output quarks are always at index 4, 5
gen_quarks = events.GenPart[events.GenPart.hasFlags(["isHardProcess"])][:, 4:6]

# %% [markdown]
# Matching efficiency calculation

# %%
def matching_efficiency(gen_quarks, vbf_jets, matching_dr=0.4, verbose=False):
    drs = ak.pad_none(vbf_jets, 2, axis=1)[:, :2].metric_table(gen_quarks)
    matched = drs < matching_dr
    # TODO: add overlap removal?
    matching_fraction = np.mean(np.all(np.any(matched, axis=2), axis=1))
    if verbose:
        print(f"Matching efficiency: {matching_fraction}")
    return matching_fraction

# %%
# ak8 jet preselection
preselection = {  # noqa: RUF012
    "pt": 300.0,
    "eta": 2.4,
    "VVmsd": 50,
    # "VVparticleNet_mass": [50, 250],
    # "bbparticleNet_mass": [92.5, 162.5],
    "bbparticleNet_mass": 50,
    "VVparticleNet_mass": 50,
    "bbFatJetParticleNetMD_Txbb": 0.8,
    "jetId": 2,  # tight ID bit
    "DijetMass": 800,  # TODO
    # "nGoodElectrons": 0,
}

# %%
num_jets = 2
fatjets = events.FatJet

fatjets = ak.pad_none(
    fatjets[(fatjets.pt > 300) * (fatjets.isTight) * (np.abs(fatjets.eta) <= 2.4)], 2, axis=1
)

# particlenet xbb vs qcd
txbb = pad_val(
    fatjets.particleNetMD_Xbb / (fatjets.particleNetMD_QCD + fatjets.particleNetMD_Xbb),
    num_jets,
    axis=1,
)

# bb VV assignment
bb_mask = txbb[:, 0] >= txbb[:, 1]
bb_mask = np.stack((bb_mask, ~bb_mask)).T

# %%
# Leptons
electrons = events.Electron
electrons = electrons[(electrons.pt > 5) & (electrons.cutBased >= electrons.LOOSE)]

muons = events.Muon
muons = muons[(muons.pt > 7) & (muons.looseId)]

# %%
sel = ak.fill_none(
    (
        (txbb[bb_mask] > 0.97)
        * (fatjets.particleNet_H4qvsQCD[~bb_mask] > 0.6)
        * (fatjets.pt[:, 0] > 500)
        * (fatjets.pt[:, 1] > 400)
        * (np.abs(fatjets[:, 0].delta_phi(fatjets[:, 1])) > 2.6)
        * (np.abs(fatjets[:, 0].eta - fatjets[:, 1].eta) < 2.0)
    ),
    False,
)

# %%
jets = events.Jet

# %% [markdown]
# # Final Selections

# %%
ak4_jet_selection = {  # noqa: RUF012
    "pt_min": 15,  # was 25
    "pt_max": 640,  # was infty
    "eta_min": 0.25,  # was 0
    "eta_max": 4.9,  # was 4.7
    "jetId": "tight",
    "puId": "medium",
    "dR_fatjetbb": 1.0,  # was 1.2
    "dR_fatjetVV": 0.75,  # was 0.8
}

vbf_jet_mask = (
    jets.isTight
    & (jets.pt >= ak4_jet_selection["pt_min"])
    & (jets.pt <= ak4_jet_selection["pt_max"])
    & (np.abs(jets.eta) <= ak4_jet_selection["eta_max"])
    & (np.abs(jets.eta) >= ak4_jet_selection["eta_min"])
    & ((jets.pt > 50) | ((jets.puId & 2) == 2))
    & (
        ak.pad_none(fatjets, num_jets, axis=1, clip=True)[bb_mask].delta_r(jets)
        > ak4_jet_selection["dR_fatjetbb"]
    )
    & (
        ak.pad_none(fatjets, num_jets, axis=1, clip=True)[~bb_mask].delta_r(jets)
        > ak4_jet_selection["dR_fatjetVV"]
    )
    & ak.all(jets.metric_table(electrons) > 0.4, axis=2)
    & ak.all(jets.metric_table(muons) > 0.4, axis=2)
)


vbf_jets = jets[vbf_jet_mask]

eff = matching_efficiency(gen_quarks[sel], vbf_jets[sel], matching_dr=0.4)
print(f"Matching efficiency: {eff}")

# %% [markdown]
# ## Comparison with an older cut

# %%
ak4_jet_selection_old = {  # noqa: RUF012
    "pt_min": 25,
    "pt_max": np.inf,
    "eta_min": 0,
    "eta_max": 4.7,
    "jetId": "tight",
    "puId": "medium",
    "dR_fatjetbb": 1.2,
    "dR_fatjetVV": 0.8,
}

# dR_fatjetVV = 0.8 used from last two cells of VBFgenInfoTests.ipynb with data generated from SM signal vbf
# https://github.com/rkansal47/HHbbVV/blob/vbf_systematics/src/HHbbVV/VBF_binder/VBFgenInfoTests.ipynb
# (0-14R1R2study.parquet) has columns of different nGoodVBFJets corresponding to R1 and R2 cuts
vbf_jet_mask_old = (
    jets.isTight
    & (jets.pt >= ak4_jet_selection_old["pt_min"])
    & (jets.pt <= ak4_jet_selection_old["pt_max"])
    & (np.abs(jets.eta) <= ak4_jet_selection_old["eta_max"])
    & (np.abs(jets.eta) >= ak4_jet_selection_old["eta_min"])
    & ((jets.pt > 50) | ((jets.puId & 2) == 2))
    & (
        ak.pad_none(fatjets, num_jets, axis=1, clip=True)[bb_mask].delta_r(jets)
        > ak4_jet_selection["dR_fatjetbb"]
    )
    & (
        ak.pad_none(fatjets, num_jets, axis=1, clip=True)[~bb_mask].delta_r(jets)
        > ak4_jet_selection["dR_fatjetVV"]
    )
    & ak.all(jets.metric_table(electrons) > 0.4, axis=2)
    & ak.all(jets.metric_table(muons) > 0.4, axis=2)
)


vbf_jets_old = jets[vbf_jet_mask_old]

eff_old = matching_efficiency(gen_quarks[sel], vbf_jets_old[sel], matching_dr=0.4)
print(f"Matching efficiency: {eff_old}")

# %%
def cut_efficiency(vbf_jets, threshold=3):
    etas = pad_val(vbf_jets.eta, 2, axis=1)
    mask = np.abs(etas[:, 0] - etas[:, 1]) > threshold
    return np.mean(mask)


print(f"Signal retain rate in new selection: {cut_efficiency(vbf_jets[sel])}")
print(f"Signal retain rate in old selection: {cut_efficiency(vbf_jets_old[sel])}")

# %%
passing_per_event = ak.count(vbf_jets.pt, axis=1)
plt.figure(figsize=(8, 8))
plt.hist(passing_per_event, bins=np.arange(0, 9), histtype="step")
plt.title("Number of VBF-Tag Jets per Event")
plt.xlabel("Jets")
plt.ylabel("Events")
plt.savefig(plot_dir / "num_passing_vbf_jets.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Effect on Background

# %%
background = nanoevents.NanoEventsFactory.from_root(
    # a random QCD sample
    "root://cmseos.fnal.gov////store/user/lpcpfnano/cmantill/v2_3/2018/QCD/QCD_HT1500to2000_TuneCP5_PSWeights_13TeV-madgraph-pythia8/QCD_HT1500to2000_PSWeights_madgraph/220808_163124/0000/nano_mc2018_1-1.root",
    schemaclass=nanoevents.NanoAODSchema,
).events()

# %%
higgs_bkg = background.GenPart[
    (abs(background.GenPart.pdgId) == HIGGS_PDGID) * background.GenPart.hasFlags(GEN_FLAGS)
]

higgs_bkg_children = higgs_bkg.children

# finding bb and VV children
is_bb_bkg = abs(higgs_bkg_children.pdgId) == b_PDGID
is_VV_bkg = (abs(higgs_bkg_children.pdgId) == W_PDGID) + (abs(higgs_bkg_children.pdgId) == Z_PDGID)

Hbb_bkg = higgs_bkg[ak.any(is_bb_bkg, axis=2)]
HVV_bkg = higgs_bkg[ak.any(is_VV_bkg, axis=2)]

# make sure we're only getting one Higgs
Hbb_bkg = ak.pad_none(Hbb_bkg, 1, axis=1)[:, 0]
HVV_bkg = ak.pad_none(HVV_bkg, 1, axis=1)[:, 0]

vs_bkg = background.GenPart[
    ((abs(background.GenPart.pdgId) == 24)) * background.GenPart.hasFlags(GEN_FLAGS)
]

# vbf output quarks are always at index 4, 5
gen_quarks_bkg = background.GenPart[background.GenPart.hasFlags(["isHardProcess"])][:, 4:6]

num_jets_bkg = 2
fatjets_bkg = background.FatJet

fatjets_bkg = ak.pad_none(
    fatjets_bkg[(fatjets_bkg.pt > 300) * (fatjets_bkg.isTight) * (np.abs(fatjets_bkg.eta) <= 2.4)],
    2,
    axis=1,
)

# particlenet xbb vs qcd
txbb_bkg = pad_val(
    fatjets_bkg.particleNetMD_Xbb / (fatjets_bkg.particleNetMD_QCD + fatjets_bkg.particleNetMD_Xbb),
    num_jets_bkg,
    axis=1,
)

# bb VV assignment
bb_mask_bkg = txbb_bkg[:, 0] >= txbb_bkg[:, 1]
bb_mask_bkg = np.stack((bb_mask_bkg, ~bb_mask_bkg)).T

# Leptons
electrons_bkg = background.Electron
electrons_bkg = electrons_bkg[
    (electrons_bkg.pt > 5) & (electrons_bkg.cutBased >= electrons_bkg.LOOSE)
]

muons_bkg = background.Muon
muons_bkg = muons_bkg[(muons_bkg.pt > 7) & (muons_bkg.looseId)]

sel_bkg = ak.fill_none(
    (
        (txbb_bkg[bb_mask_bkg] > 0.97)
        * (fatjets_bkg.particleNet_H4qvsQCD[~bb_mask_bkg] > 0.6)
        * (fatjets_bkg.pt[:, 0] > 500)
        * (fatjets_bkg.pt[:, 1] > 400)
        * (np.abs(fatjets_bkg[:, 0].delta_phi(fatjets_bkg[:, 1])) > 2.6)
        * (np.abs(fatjets_bkg[:, 0].eta - fatjets_bkg[:, 1].eta) < 2.0)
    ),
    False,
)

jets_bkg = background.Jet

bkg_jet_mask = (
    jets_bkg.isTight
    & (jets_bkg.pt >= ak4_jet_selection["pt_min"])
    & (jets_bkg.pt <= ak4_jet_selection["pt_max"])
    & (np.abs(jets_bkg.eta) <= ak4_jet_selection["eta_max"])
    & (np.abs(jets_bkg.eta) >= ak4_jet_selection["eta_min"])
    & ((jets_bkg.pt > 50) | ((jets_bkg.puId & 2) == 2))
    & (
        ak.pad_none(fatjets_bkg, num_jets_bkg, axis=1, clip=True)[bb_mask_bkg].delta_r(jets_bkg)
        > ak4_jet_selection["dR_fatjetbb"]
    )
    & (
        ak.pad_none(fatjets_bkg, num_jets_bkg, axis=1, clip=True)[~bb_mask_bkg].delta_r(jets_bkg)
        > ak4_jet_selection["dR_fatjetVV"]
    )
    & ak.all(jets_bkg.metric_table(electrons_bkg) > 0.4, axis=2)
    & ak.all(jets_bkg.metric_table(muons_bkg) > 0.4, axis=2)
)

bkg_jets = jets_bkg[bkg_jet_mask]

print(f"Background retain rate in new selection: {cut_efficiency(bkg_jets[sel_bkg])}")

# %% [markdown]
# # Selection analysis
# We define true VBF jets as jets that are matched to the generator-level quarks.
# - We define fake VBF jets as jets that are not matched to the generator-level quarks.
#
# We are interested in the following categories.
# - `true_vbf_jets_selected`: true VBF jets that pass our selection (`vbf_jet_masked`).
# - `true_vbf_jets_unselected`: true VBF jets that do not pass our selection (`vbf_jet_masked`).
# - `fake_vbf_jets_selected`: jets that pass the selection (`vbf_jet_masked`) but are not true VBF jets.

# %%
# jets that pass the VBF selection (without selecting the two highest pT jets yet)
jets = events.Jet
jets = jets[sel]

# ak4_jet_selection = {  # noqa: RUF012
#     "pt_min": 25,
#     "pt_max": np.inf,
#     "eta_min": 0,
#     "eta_max": 4.7,
#     "jetId": "tight",
#     "puId": "medium",
#     "dR_fatjetbb": 1.2,
#     "dR_fatjetVV": 0.8,
# }

ak4_jet_selection = {  # noqa: RUF012
    "pt_min": 15,  # was 25
    "pt_max": 640,  # was infty
    "eta_min": 0.25,  # was 0
    "eta_max": 4.9,  # was 4.7
    "jetId": "tight",
    "puId": "medium",
    "dR_fatjetbb": 1.0,  # was 1.2
    "dR_fatjetVV": 0.75,  # was 0.8
}

# ak4_jet_selection = {  # noqa: RUF012
#     "pt_min": 25,  # was 25
#     "pt_max": 640,  # was infty
#     "eta_min": 2.0,  # was 0
#     "eta_max": 4.9,  # was 4.7
#     "jetId": "tight",
#     "puId": "medium",
#     "dR_fatjetbb": 2.0,  # was 1.2
#     "dR_fatjetVV": 2.0,  # was 0.8
# }


vbf_jet_mask = (
    jets.isTight
    & (jets.pt >= ak4_jet_selection["pt_min"])
    & (jets.pt <= ak4_jet_selection["pt_max"])
    & (np.abs(jets.eta) <= ak4_jet_selection["eta_max"])
    & (np.abs(jets.eta) >= ak4_jet_selection["eta_min"])
    & ((jets.pt > 50) | ((jets.puId & 2) == 2))
    & (
        ak.pad_none(fatjets[sel], num_jets, axis=1, clip=True)[bb_mask[sel]].delta_r(jets)
        > ak4_jet_selection["dR_fatjetbb"]
    )
    & (
        ak.pad_none(fatjets[sel], num_jets, axis=1, clip=True)[~bb_mask[sel]].delta_r(jets)
        > ak4_jet_selection["dR_fatjetVV"]
    )
    & ak.all(jets.metric_table(electrons[sel]) > 0.4, axis=2)
    & ak.all(jets.metric_table(muons[sel]) > 0.4, axis=2)
)
jets_selected = jets[vbf_jet_mask]

# true jets
matching_dr = 0.4
drs = jets.metric_table(gen_quarks[sel])
matched = ak.any(drs < matching_dr, axis=2)

true_vbf_jets_selected = jets[vbf_jet_mask][:, :2][matched[vbf_jet_mask][:, :2]]
true_vbf_jets_unselected_by_ak4 = jets[~vbf_jet_mask][matched[~vbf_jet_mask]]
true_vbf_jets_unselected_by_2pt = jets[vbf_jet_mask][:, 2:][matched[vbf_jet_mask][:, 2:]]
false_vbf_jets_selected = jets[vbf_jet_mask][:, :2][~matched[vbf_jet_mask][:, :2]]

n_jets = len(ak.flatten(jets))
n_true_vbf_jets = len(ak.flatten(jets[matched]))
n_jets_selected = len(ak.flatten(jets[vbf_jet_mask][:, :2]))
n_true_vbf_jets_selected = len(ak.flatten(jets[vbf_jet_mask][:, :2]))
n_true_vbf_jets_selected = len(ak.flatten(true_vbf_jets_selected))
n_true_vbf_jets_selected_by_ak4 = len(ak.flatten(true_vbf_jets_unselected_by_ak4))
n_true_vbf_jets_selected_by_2pt = len(ak.flatten(true_vbf_jets_unselected_by_2pt))
n_false_vbf_jets_selected = len(ak.flatten(false_vbf_jets_selected))

print(f"Number of Jets: {n_jets}")
print(f"Number of True VBF Jets: {n_true_vbf_jets}")
print(f"Number of Jets Selected: {n_jets_selected}")
print(
    f"Number of True VBF Jets Selected: {n_true_vbf_jets_selected} ({n_true_vbf_jets_selected/n_true_vbf_jets * 100:.2f}%)"
)
print(
    f"Number of True VBF Jets Unselected by ak4: {n_true_vbf_jets_selected_by_ak4} ({n_true_vbf_jets_selected_by_ak4/n_true_vbf_jets * 100:.2f}%)"
)
print(
    f"Number of True VBF Jets Unselected by pt: {n_true_vbf_jets_selected_by_2pt} ({n_true_vbf_jets_selected_by_2pt/n_true_vbf_jets * 100:.2f}%)"
)
print(f"Number of False VBF Jets Selected: {n_false_vbf_jets_selected}")
print(
    f"Fraction of True VBF Jets in Selected Jets: {n_true_vbf_jets_selected / (n_true_vbf_jets_selected + n_false_vbf_jets_selected) * 100:.2f}%"
)

# %%
# mass
for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(0, 40, 1)
    plt.hist(
        ak.flatten(true_vbf_jets_selected.mass),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_ak4.mass),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_2pt.mass),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        ak.flatten(false_vbf_jets_selected.mass),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("$m_j$ (GeV)")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_mass{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %%
# pt
for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(0, 300, 10)
    plt.hist(
        ak.flatten(true_vbf_jets_selected.pt),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_ak4.pt),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_2pt.pt),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        ak.flatten(false_vbf_jets_selected.pt),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("${p_\mathrm{T}}_j$ (GeV)")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_pt{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %%
# |eta|
for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(0, 5, 0.1)
    plt.hist(
        np.abs(ak.flatten(true_vbf_jets_selected.eta)),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            np.abs(ak.flatten(true_vbf_jets_unselected_by_ak4.eta)),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            np.abs(ak.flatten(true_vbf_jets_unselected_by_2pt.eta)),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        np.abs(ak.flatten(false_vbf_jets_selected.eta)),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("$|\eta_j|$")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_eta{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %%
# eta_jj
true_vbf_jets_selected_padded = ak.pad_none(true_vbf_jets_selected, 2, axis=1)
# true_vbf_jets_unselected_padded = ak.pad_none(true_vbf_jets_unselected, 2, axis=1)
true_vbf_jets_unselected_by_ak4_padded = ak.pad_none(true_vbf_jets_unselected_by_ak4, 2, axis=1)
true_vbf_jets_unselected_by_2pt_padded = ak.pad_none(true_vbf_jets_unselected_by_2pt, 2, axis=1)
false_vbf_jets_selected_padded = ak.pad_none(false_vbf_jets_selected, 2, axis=1)

for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(1e-4, 10, 0.2)

    plt.hist(
        np.abs(true_vbf_jets_selected_padded.eta[:, 0] - true_vbf_jets_selected_padded.eta[:, 1]),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            np.abs(
                true_vbf_jets_unselected_by_ak4_padded.eta[:, 0]
                - true_vbf_jets_unselected_by_ak4_padded.eta[:, 1]
            ),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            np.abs(
                true_vbf_jets_unselected_by_2pt_padded.eta[:, 0]
                - true_vbf_jets_unselected_by_2pt_padded.eta[:, 1]
            ),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        np.abs(false_vbf_jets_selected_padded.eta[:, 0] - false_vbf_jets_selected_padded.eta[:, 1]),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("$\eta_{jj}$")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_eta_jj{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %%
# dR(j, Hbb)
for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(0, 7, 0.2)
    plt.hist(
        ak.flatten(true_vbf_jets_selected.delta_r(Hbb[sel])),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_ak4.delta_r(Hbb[sel])),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_2pt.delta_r(Hbb[sel])),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        ak.flatten(false_vbf_jets_selected.delta_r(Hbb[sel])),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("$\Delta R(j, Hbb)$")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_dR_Hbb{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %%
# dR(j, HVV)
for ylabel, name_label, density in zip(
    ("Jets", "Jets (A.U)"),
    ("", "_density"),
    (False, True),
):
    plt.figure(figsize=(10, 10))
    bins = np.arange(0, 7, 0.2)
    plt.hist(
        ak.flatten(true_vbf_jets_selected.delta_r(HVV[sel])),
        bins=bins,
        histtype="step",
        density=density,
        label=f"True VBF Jets Selected ({n_true_vbf_jets_selected} Jets)",
    )

    if n_true_vbf_jets_selected_by_ak4 > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_2pt.delta_r(HVV[sel])),
            bins=bins,
            histtype="step",
            density=density,
            label=f"True VBF Jets Unselected by AK4 ({n_true_vbf_jets_selected_by_ak4} Jets)",
        )

    if n_true_vbf_jets_selected_by_2pt > 0:
        plt.hist(
            ak.flatten(true_vbf_jets_unselected_by_ak4.delta_r(HVV[sel])),
            bins=bins,
            histtype="step",
            density=density,
            label=r"True VBF Jets Unselected by $p_\mathrm{T}$ "
            + f"({n_true_vbf_jets_selected_by_2pt} Jets)",
        )

    plt.hist(
        ak.flatten(false_vbf_jets_selected.delta_r(HVV[sel])),
        bins=bins,
        histtype="step",
        density=density,
        label=f"False VBF Jets Selected ({n_false_vbf_jets_selected} Jets)",
    )

    plt.legend(loc="upper right")
    plt.xlabel("$\Delta R(j, HVV)$")
    plt.ylabel(ylabel)
    plt.savefig(plot_dir / f"vbf_jet_selection_dR_HVV{name_label}.pdf", bbox_inches="tight")
    plt.show()

# %% [markdown]
# # Events that Have Two VBF Jets

# %%
matched = ak.any(drs < matching_dr, axis=2)
# select events with two true VBF jets
two_vbf = ak.sum(matched, axis=1) == 2
jets_two_vbf = jets[two_vbf]
jets_two_vbf

# %%
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(jets_two_vbf.mass),
    bins=np.arange(0, 160, 5),
    histtype="step",
    density=True,
)
plt.xlabel("$m$ (GeV)")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_mass.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(jets_two_vbf.pt),
    bins=np.arange(0, 1400, 20),
    histtype="step",
    density=True,
)
plt.xlabel("$p_\mathrm{T}$ (GeV)")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_pt.pdf", bbox_inches="tight")
plt.show()

# %%
# |eta|
plt.figure(figsize=(10, 10))
plt.hist(
    np.abs(ak.flatten(jets_two_vbf.eta)),
    bins=np.arange(0, 5.5, 0.1),
    histtype="step",
    density=True,
)
plt.xlabel("$|\eta|$")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_eta.pdf", bbox_inches="tight")
plt.show()

# %%
# eta_jj
jets_two_vbf_padded = ak.pad_none(jets_two_vbf, 2, axis=1)
plt.figure(figsize=(10, 10))
plt.hist(
    np.abs(jets_two_vbf_padded.eta[:, 0] - jets_two_vbf_padded.eta[:, 1]),
    bins=np.arange(0, 2.5, 0.1),
    histtype="step",
    density=True,
)
plt.xlabel("$\eta_{jj}$")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_eta_jj.pdf", bbox_inches="tight")
plt.show()

# %%
# dR(j, Hbb)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(jets_two_vbf.delta_r(Hbb[sel][two_vbf])),
    bins=np.arange(0, 7, 0.1),
    histtype="step",
    density=True,
)
plt.xlabel("$\Delta R(j, Hbb)$")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_dR_Hbb.pdf", bbox_inches="tight")
plt.show()

# %%
# dR(j, HVV)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(jets_two_vbf.delta_r(HVV[sel][two_vbf])),
    bins=np.arange(0, 7, 0.1),
    histtype="step",
    density=True,
)
plt.xlabel("$\Delta R(j, HVV)$")
plt.ylabel("Jets (A.U.)")
plt.title("Events with Two VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_dR_HVV.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Events which have 1 true and 1 “fake” vbf jet selected
# - `dR(true selected, fake selected)`
# - `dR(true selected, true unselected_ak4)`
# - `dR(true selected, true unselected_pt)`

# %%
events_one_vbf = jets[ak.sum(matched, axis=1) == 1]
events_two_vbf = jets[ak.sum(matched, axis=1) == 2]
events_three_vbf = jets[ak.sum(matched, axis=1) == 3]
events_two_vbf

# %%
def events_ak4_selected(jets, fatjets, bb_mask, electrons, muons, num_jets: int = 2):
    ak4_jet_selection = {  # noqa: RUF012
        "pt_min": 15,  # was 25
        "pt_max": 640,  # was infty
        "eta_min": 0.25,  # was 0
        "eta_max": 4.9,  # was 4.7
        "jetId": "tight",
        "puId": "medium",
        "dR_fatjetbb": 1.0,  # was 1.2
        "dR_fatjetVV": 0.75,  # was 0.8
    }

    vbf_jet_mask = (
        jets.isTight
        & (jets.pt >= ak4_jet_selection["pt_min"])
        & (jets.pt <= ak4_jet_selection["pt_max"])
        & (np.abs(jets.eta) <= ak4_jet_selection["eta_max"])
        & (np.abs(jets.eta) >= ak4_jet_selection["eta_min"])
        & ((jets.pt > 50) | ((jets.puId & 2) == 2))
        & (
            ak.pad_none(fatjets, num_jets, axis=1, clip=True)[bb_mask].delta_r(jets)
            > ak4_jet_selection["dR_fatjetbb"]
        )
        & (
            ak.pad_none(fatjets, num_jets, axis=1, clip=True)[~bb_mask].delta_r(jets)
            > ak4_jet_selection["dR_fatjetVV"]
        )
        & ak.all(jets.metric_table(electrons) > 0.4, axis=2)
        & ak.all(jets.metric_table(muons) > 0.4, axis=2)
    )
    jets_selected = jets[vbf_jet_mask]

    return jets_selected, vbf_jet_mask

# %%
selection_two_vbf = ak.sum(matched, axis=1) == 2
events_two_vbf = jets[selection_two_vbf]
matched_two_vbf = matched[selection_two_vbf]

_, events_two_vbf_ak4_mask = events_ak4_selected(
    events_two_vbf,
    fatjets[sel][selection_two_vbf],
    bb_mask[sel][selection_two_vbf],
    electrons[sel][selection_two_vbf],
    muons[sel][selection_two_vbf],
)

# vbf jet(s) in each event that are selected by ak4
events_two_vbf_ak4_selected = events_two_vbf[events_two_vbf_ak4_mask][:, :2][
    matched_two_vbf[events_two_vbf_ak4_mask][:, :2]
]

# vbf jet(s) in each event that are not selected by ak4
events_two_vbf_ak4_unselected = events_two_vbf[~events_two_vbf_ak4_mask][
    matched_two_vbf[~events_two_vbf_ak4_mask]
]
# wrong jet(s) in each event that are selected by ak4
events_two_vbf_ak4_wrong = events_two_vbf[events_two_vbf_ak4_mask][:, :2][
    ~matched_two_vbf[events_two_vbf_ak4_mask][:, :2]
]
# vbf jet(s) in each event that are selected by pT
events_two_vbf_pt_unselected = events_two_vbf[events_two_vbf_ak4_mask][:, 2:][
    matched_two_vbf[events_two_vbf_ak4_mask][:, 2:]
]

# %%
# sanity check for no unselected events
for i in range(len(events_two_vbf)):
    assert (
        len(events_two_vbf_ak4_selected[i])
        + len(events_two_vbf_ak4_unselected[i])
        + len(events_two_vbf_pt_unselected[i])
    ) == 2, i

# %%
events_two_vbf_two_selected_mask = ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 2
events_two_vbf_one_selected_one_unselected_by_ak4_mask = (
    ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 1
) & (ak.count(events_two_vbf_ak4_unselected.pt, axis=1) == 1)
events_two_vbf_one_selected_one_unselected_by_pt_mask = (
    ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 1
) & (ak.count(events_two_vbf_pt_unselected.pt, axis=1) == 1)
events_two_vbf_two_unselected_by_ak4_mask = (
    ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 0
) & (ak.count(events_two_vbf_ak4_unselected.pt, axis=1) == 2)
events_two_vbf_two_unselected_by_pt_mask = (
    ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 0
) & (ak.count(events_two_vbf_pt_unselected.pt, axis=1) == 2)
events_two_vbf_one_unselected_by_ak4_one_unselected_by_pt_mask = (
    ak.count(events_two_vbf_ak4_unselected.pt, axis=1) == 1
) & (ak.count(events_two_vbf_pt_unselected.pt, axis=1) == 1)
events_two_vbf_one_selected_one_wrong_mask = (
    ak.count(events_two_vbf_ak4_selected.pt, axis=1) == 1
) & (ak.count(events_two_vbf_ak4_wrong.pt, axis=1) == 1)

# %%
# dR(true, fake)
true = events_two_vbf_ak4_selected[events_two_vbf_one_selected_one_wrong_mask]
fake = events_two_vbf_ak4_wrong[events_two_vbf_one_selected_one_wrong_mask]
dR = true.delta_r(fake)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 10, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Selected}, \mathrm{Fake Selected})$")
plt.ylabel("Jets")
plt.title("Selections with One True and One Fake VBF Jet")
plt.savefig(plot_dir / "two_vbf_events_jet_dR_true_fake.pdf", bbox_inches="tight")
plt.show()

# %%
# dR(true_selected, true_unselected_by_ak4)
true_selected = events_two_vbf_ak4_selected[events_two_vbf_one_selected_one_unselected_by_ak4_mask]
true_unselected_by_ak4 = events_two_vbf_ak4_unselected[
    events_two_vbf_one_selected_one_unselected_by_ak4_mask
]
dR = true_selected.delta_r(true_unselected_by_ak4)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0.4, 0.7, 0.02),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Selected}, \mathrm{True Unselected By AK4})$")
plt.ylabel("Jets")
plt.title("Events with One Selected and\nOne Unselected VBF Jet by AK4")
plt.savefig(
    plot_dir / "two_vbf_events_jet_dR_true_selected_true_unselected_by_ak4.pdf", bbox_inches="tight"
)
plt.show()

# %%
# dR(true_selected, true_unselected_by_pt)
true_selected = events_two_vbf_ak4_selected[events_two_vbf_one_selected_one_unselected_by_pt_mask]
true_unselected_by_pt = events_two_vbf_pt_unselected[
    events_two_vbf_one_selected_one_unselected_by_pt_mask
]
dR = true_selected.delta_r(true_unselected_by_pt)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 10, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Selected}, \mathrm{True Unselected By }P_T)$")
plt.ylabel("Jets")
plt.title("Events with One Selected and\nOne Unselected VBF Jet by $p_T$")
plt.savefig(
    plot_dir / "two_vbf_events_jet_dR_true_selected_true_unselected_by_pt.pdf", bbox_inches="tight"
)

# %%
# dR(true_selected, true_selected)
true_selected = events_two_vbf_ak4_selected[events_two_vbf_two_selected_mask]
jet1 = true_selected[:, :1]
jet2 = true_selected[:, 1:]
dR = jet1.delta_r(jet2)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 10.5, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Selected}, \mathrm{True Selected})$")
plt.ylabel("Jets")
plt.title("Events with Two Selected VBF Jets")
plt.savefig(plot_dir / "two_vbf_events_jet_dR_true_selected_true_selected.pdf", bbox_inches="tight")
plt.show()

# %%
# dR(true_unselected_by_ak4, true_unselected_by_ak4)
true_unselected_by_ak4 = events_two_vbf_ak4_unselected[events_two_vbf_two_unselected_by_ak4_mask]
jet1 = true_unselected_by_ak4[:, :1]
jet2 = true_unselected_by_ak4[:, 1:]
dR = jet1.delta_r(jet2)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 15, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Unselected By AK4}, \mathrm{True Unselected By AK4})$")
plt.ylabel("Jets")
plt.title("Events with Two Unselected VBF Jets by AK4")
plt.savefig(
    plot_dir / "two_vbf_events_jet_dR_true_unselected_by_ak4_true_unselected_by_ak4.pdf",
    bbox_inches="tight",
)
plt.show()

# %%
# dR(true_unselected_by_pt, true_unselected_by_pt)
true_unselected_by_pt = events_two_vbf_pt_unselected[events_two_vbf_two_unselected_by_pt_mask]
jet1 = true_unselected_by_pt[:, :1]
jet2 = true_unselected_by_pt[:, 1:]
dR = jet1.delta_r(jet2)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 15, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Unselected By }P_T, \mathrm{True Unselected By }P_T)$")
plt.ylabel("Jets")
plt.title("Events with Two Unselected VBF Jets by $p_T$")
plt.savefig(
    plot_dir / "two_vbf_events_jet_dR_true_unselected_by_pt_true_unselected_by_pt.pdf",
    bbox_inches="tight",
)
plt.show()

# %%
# dR(true_unselected_by_ak4, true_unselected_by_pt)
true_unselected_by_ak4 = events_two_vbf_ak4_unselected[
    events_two_vbf_one_unselected_by_ak4_one_unselected_by_pt_mask
]
true_unselected_by_pt = events_two_vbf_pt_unselected[
    events_two_vbf_one_unselected_by_ak4_one_unselected_by_pt_mask
]
dR = true_unselected_by_ak4.delta_r(true_unselected_by_pt)
plt.figure(figsize=(10, 10))
plt.hist(
    ak.flatten(dR),
    bins=np.arange(0, 15, 0.5),
    histtype="step",
    density=False,
)
plt.xlabel("$\Delta R(\mathrm{True Unselected By AK4}, \mathrm{True Unselected By }P_T)$")
plt.ylabel("Jets")
plt.title("Events with One Unselected VBF Jet by AK4\nand One Unselected VBF Jet by $p_T$")
plt.savefig(
    plot_dir / "two_vbf_events_jet_dR_true_unselected_by_ak4_true_unselected_by_pt.pdf",
    bbox_inches="tight",
)
plt.show()

# %% [markdown]
# # Selection with One True and One Fake VBF Jet

# %% [markdown]
# ## Analysis of AK4 and $p_\mathrm{T}$ selections

# %%
# events in which one ak4 selection is correct and one is wrong
ak4_mask_events_two_vbf_one_selected_one_wrong = events_two_vbf_ak4_mask[
    events_two_vbf_one_selected_one_wrong_mask
]
matched_mask_events_two_vbf_one_selected_one_wrong = matched_two_vbf[
    events_two_vbf_one_selected_one_wrong_mask
]

# %%
def mask_false_n_trues(events: ak.Array, n: int) -> ak.Array:
    masked_events_list = []

    for event in events:
        # Convert the event to a NumPy array for easier manipulation
        np_event = ak.to_numpy(event)
        true_indices = np.where(np_event)[0]
        if len(true_indices) > n:
            # If more than two Trues, mask the rest after the first two
            mask_indices = true_indices[2:]  # Indices of Trues to be masked
            np_event[mask_indices] = False
        # Append the modified event back to the list
        masked_events_list.append(np_event)

    # Convert the list back to an awkward array
    masked_events = ak.Array(masked_events_list)
    return masked_events


ak4_pt_mask_events_two_vbf_one_selected_one_wrong = mask_false_n_trues(
    ak4_mask_events_two_vbf_one_selected_one_wrong, 2
)  # Mask all but the first two Trues to get the pT selection

# %%
def true_indices(events: ak.Array) -> ak.Array:
    true_indices_list = []

    for event in events:
        np_event = ak.to_numpy(event)
        true_indices = np.where(np_event)[0]
        true_indices_list.append(true_indices)

    true_indices = ak.Array(true_indices_list)
    return true_indices


pt_rank_true_selected = ak.flatten(
    true_indices(
        (
            ak4_pt_mask_events_two_vbf_one_selected_one_wrong
            & matched_mask_events_two_vbf_one_selected_one_wrong
        )
    )
)
pt_rank_fake_selected = ak.flatten(
    true_indices(
        (
            ak4_pt_mask_events_two_vbf_one_selected_one_wrong
            & ~matched_mask_events_two_vbf_one_selected_one_wrong
        )
    )
)
pt_rank_true_unselected = ak.flatten(
    true_indices(
        (
            ~ak4_pt_mask_events_two_vbf_one_selected_one_wrong
            & matched_mask_events_two_vbf_one_selected_one_wrong
        )
    )
)

# %%
for density, ylabel, plot_label in zip(
    (False, True),
    ("Events", "Events (A.U.)"),
    ("", "_density"),
):
    plt.figure(figsize=(10, 10))
    plt.hist(
        pt_rank_true_selected + 1,
        bins=np.arange(1, 14, 1),
        histtype="step",
        density=density,
        label="True Selected",
    )
    plt.hist(
        pt_rank_fake_selected + 1,
        bins=np.arange(1, 14, 1),
        histtype="step",
        density=density,
        label="Fake Selected",
    )
    plt.hist(
        pt_rank_true_unselected + 1,
        bins=np.arange(1, 14, 1),
        histtype="step",
        density=density,
        label="True Unselected",
    )
    plt.xlabel("Rank by $p_T$ (Counting from 1)")
    plt.ylabel(ylabel)
    plt.title("Events with One Selected True\nand One Fake Selected VBF Jet")
    plt.legend(loc="upper right")
    plt.savefig(
        plot_dir / f"two_vbf_events_one_true_one_fake_jet_pt_rank{plot_label}.pdf",
        bbox_inches="tight",
    )
    plt.show()

# %% [markdown]
# ## Analysis of $p_\mathrm{T}$ Selections

# %%
selection_two_vbf = ak.sum(matched, axis=1) == 2
events_two_vbf = jets[selection_two_vbf]
matched_two_vbf = matched[selection_two_vbf]

_, events_two_vbf_ak4_mask = events_ak4_selected(
    events_two_vbf,
    fatjets[sel][selection_two_vbf],
    bb_mask[sel][selection_two_vbf],
    electrons[sel][selection_two_vbf],
    muons[sel][selection_two_vbf],
)
# vbf jet(s) in each event that are selected by ak4
events_two_vbf_ak4_selected = events_two_vbf[events_two_vbf_ak4_mask][:, :2][
    matched_two_vbf[events_two_vbf_ak4_mask][:, :2]
]

# vbf jet(s) in each event that are not selected by ak4
events_two_vbf_ak4_unselected = events_two_vbf[~events_two_vbf_ak4_mask][
    matched_two_vbf[~events_two_vbf_ak4_mask]
]
# wrong jet(s) in each event that are selected by ak4
events_two_vbf_ak4_wrong = events_two_vbf[events_two_vbf_ak4_mask][:, :2][
    ~matched_two_vbf[events_two_vbf_ak4_mask][:, :2]
]
# vbf jet(s) in each event that are selected by pT
events_two_vbf_pt_unselected = events_two_vbf[events_two_vbf_ak4_mask][:, 2:][
    matched_two_vbf[events_two_vbf_ak4_mask][:, 2:]
]

true_unselected_by_pt_lists = []
for i in range(len(events_two_vbf)):
    ak4_mask = events_two_vbf_ak4_mask[i]
    matched_mask = matched_two_vbf[i]

    true_unselected_by_pt_list = []
    ak4_jet_idx = 0
    for j in range(len(ak4_mask)):
        if ak4_mask[j] and matched_mask[j]:
            if ak4_jet_idx >= 2:
                true_unselected_by_pt_list.append(ak4_jet_idx)
            else:
                pass
        if ak4_mask[j]:
            ak4_jet_idx += 1
    true_unselected_by_pt_lists.append(true_unselected_by_pt_list)
true_unselected_by_pt_lists = ak.flatten(ak.Array(true_unselected_by_pt_lists))

# %%
for density, ylabel, plot_label in zip(
    (False, True),
    ("Events", "Events (A.U.)"),
    ("", "_density"),
):
    plt.figure(figsize=(10, 10))
    plt.hist(
        true_unselected_by_pt_lists + 1,
        bins=np.arange(1, 8, 1),
        histtype="step",
        density=density,
    )
    plt.xlabel("Rank by $p_T$ in AK4 Selection (Counting from 1)")
    plt.ylabel(ylabel)
    plt.title("Events with Unselected True VBF Jets by $p_T$")
    plt.savefig(
        plot_dir / f"two_vbf_events_unselected_by_pt_ak4_selection_pt_rank{plot_label}.pdf",
        bbox_inches="tight",
    )
